# %% [markdown]
# # Para iniciarmos a resolução dessa prova, irei apresentar todos os comandos utilizados, caso queira se interar mais no assunto, recomendo o material criado pelo professor Ricardo que se chama: *"Tutorial rápido de Python para Matemáticos"* e pode ser encontrado no link: (https://rmiranda99.github.io/tutorial-math-python/6-limites-derivadas-integrais.html) LINK ONDE ENCONTRA-SE A RESOLUÇÃO DESSA PROVA: (https://www.ime.unicamp.br/~andreani/MA141/Provas%20Anteriores/segundaprova17.05.2011tarde.pdf)

# %% [markdown]
# E também usaremos o matrix calc(https://matrixcalc.org/pt) para escalonar as matrizes e obtermos o estudo dos sistemas

# %% [markdown]
# 1) A)   Encontrar a equação do plano que passe pelo ponto $P=(1,2,1)$ e que contém a reta interseção entre os planos $\pi :2x-3y+4z$ e $\alpha :x-3y-2z+2$.

# %% [markdown]
# Primeiramente vamos plotar os 2 planos no geogebra. Basta digitar a equação deles no software e obteremos isso:
# ![image.png](attachment:image.png)
# Agora vamos achar a interseção entre os planos basta escrever interseção no geogebra e escolher a primeira opção, marcando depois o plano 1 e o plano 2. Assim obteremmos:
# ![image-2.png](attachment:image-2.png)
# Agora vamos plotar o ponto e fazer o plano entre a reta (que é a interseção entre os outros dois planos) e o ponto do enunciado. Basta escrever plano no software, escolher a terceira opção, e colocar a reta e o ponto. Assim obteremos:
# ![image-3.png](attachment:image-3.png)
# Portanto a equação do plano é:
# $$9x-12y+22z=7$$

# %% [markdown]
# 2. Verifique se as afirmações abaixo são verdadeiras. Justifique.

# %% [markdown]
# a) Os vetores $\vec{u}=(2,1,-1)$, $\vec{v}=(1,2,2)$ e $\vec{w}=(1,5,7)$ são cooplanares.

# %% [markdown]
# Para saber se os vetores são cooplanares, basta fazer a determinante dos 3. E para isso usaremos o python. Usaremos a seguinte matriz: $$\begin{vmatrix}
# 1 & 5 & 7\\
# 2 & 1 & -1\\
# 1 & 2 & 2
# \end{vmatrix}$$

# %%
import numpy as np 
from numpy import linalg 
matrix = np.array([[1, 5, 7], [2, 1,-1], [1, 2, 2]]) 
matrix=np.linalg.det(matrix)
matrix
# Out:
# 0.0

# %% [markdown]
# Como $det=0$ os vetores são cooplanares.

# %% [markdown]
# b)Se $\vec{u}$ e $\vec{v}$ são dois vetores então $\left | \vec{u}\cdot \vec{v} \right |$ é área do paralelogramo determinado por $\vec{u}$ e $\vec{v}$

# %% [markdown]
# Seja $u=(1,0,0)$ e $v=(0,1,0)$ logo $\left | \vec{u}\cdot \vec{v} \right |=0$ portanto $\left | \vec{u}\cdot \vec{v} \right |$ não é a àrea do paralelogramo.

# %% [markdown]
# c)O vetor $(\vec{u}\times \vec{v})\times \vec{w}$ é perpendicular ao vetor $\vec{u}$

# %% [markdown]
# Seja $u=(0,1,0)$ $v=(0,0,1)$ e $w=(0,-\frac{\sqrt{2}}{2},\frac{\sqrt{2}}{2})$\
# $u\times v=\begin{vmatrix}
# \hat{i} & \hat{j} & \hat{k}\\
# 0 & 1 & 0\\
# 0 & 0 & 1
# \end{vmatrix} = \hat{i}$
#
# $(u\times v)\times w=\begin{vmatrix}
# \hat{i} & \hat{j} & \hat{k}\\
# 1 & 0 & 0\\
# 0 & -\frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}
# \end{vmatrix} = -\frac{\sqrt{2}}{2}\hat{i}-\frac{\sqrt{2}}{2}\hat{k}$
#
# $((u\times v)\times w)\cdot \vec{u}=(0,-\frac{\sqrt{2}}{2},-\frac{\sqrt{2}}{2})\cdot (0,1,0)=-\frac{\sqrt{2}}{2}\neq 0$

# %% [markdown]
# Como $((u\times v)\times w)\cdot \vec{u} \neq 0$ a afirmação é falsa

# %% [markdown]
# d)A equação $r(1-cos2\theta)=1$ em coordenadas polares representa uma elipse.

# %% [markdown]
# $$r(1-cos\theta )=1$$
# $$r-2x=1$$
# $$x^2-2x+1+y^2=2$$
# $$(x-1)^2+y^2=2$$
# Isso é uma circunferência e não uma elipse.

# %% [markdown]
# e)Se $\vec{u}$ e $\vec{v}$ são dois vetores então

# %% [markdown]
# $u=(1,0,0)$ $v=(1,0,0)$ $u\times v=0$ $\left | u \right |=1$ $\left | v \right |=1$

# %% [markdown]
# $$\left | \vec{u} \right |\left | \vec{v} \right |\leq \left | \vec{u}\times\vec{v}  \right |$$
# $$\left | u\times v \right |=\left | u \right |\left | v \right |sen(\hat{uv})$$
# Falso.

# %% [markdown]
# 3)Considere as retas $r_1$ e $r_2$ dadas por: $r_1:x=0, y=2+t$ e $z=1+t$; $r_2$ é a interseção dos planos $2x-2z-6=0$ e $y=3$

# %% [markdown]
# a)Mostre que $r_1$ e $r_2$ são reversas.

# %% [markdown]
# $$P_{r_1}=(0,2,1)\quad  v_{r_1}=(0,1,1) $$
# $$P_{r_1}=(3,3,0)\quad  v_{r_1}=(1,0,1) $$
# $$n=v_{r_1}\times v_{r_1}=\begin{vmatrix}
# \hat{i} & \hat{j} & \hat{k}\\
# 0 & 1 &1 \\
# 1 & 0 &1
# \end{vmatrix}=\hat{i}+\hat{j}-\hat{k}$$
# P_{r_2}-P_{r_1}=(3,3,0)-(0,2,1)=(3,1,-1)=\overrightarrow{P_{r1}P_{r2}}
# $$\overrightarrow{P_{r1}P_{r2}}*n=(3,1,-1)\cdot (1,1,-1)=3+1+1=5\neq 0$$
# Logo são reversas, pois $\overrightarrow{P_{r1}P_{r2}}*n\neq 0$

# %% [markdown]
# b)Encontrar os planos $\pi$ e $\alpha$ tais que: $r_1\subset \pi, r_2\subset \alpha $ e $\pi $ é paralelo a $\alpha$.

# %% [markdown]
# $$\vec{n}=(1,1,-1)$$
# $$\pi :(1,1,-1)(x,y-2,z-1)=0$$
# $$\pi :x+y-z-1=0$$
# $$\alpha :(1,1,-1)(x-3,y-3,z)=0$$
# $$\alpha :x+y-z-6=0$$

# %% [markdown]
# c)Encontrar a distância entre os planos do item anterior.

# %% [markdown]
# Para resolver essa questão, vamos plotar os planos anteriores no geogebra e obteremos:
# ![image.png](attachment:image.png)
# E escrever distância, selecionar a terceira opção, marcar os 2 planos e assim obtemos:
# ![image-2.png](attachment:image-2.png)
# Logo a distancia é de $2,89$

# %% [markdown]
# d)Encontrar os pontos $P_1$ em $r_1$ e $P_2$ em $r_2$ tais que a reta que passa por $P_1$ e $P_2$ seja perpendincular a $r_1$ e $r_2$

# %% [markdown]
# $$P_1=(0,2,1)+t^*(0,1,1)=(0,2-t^*,1-t^*)$$
# $$P_2=(3,3,0)+t^*(1,0,1)=(3+s^*,3,s^*)$$
# $$P_2-P_1=(3+s^*,1+t^*,-1+t^*+s^*)=\alpha (1,1,-1)\rightarrow $$
# $$\left\{\begin{matrix}
# 3+s^*=\alpha \\
# 1+t^*=\alpha \\
# -1+s^*+t^*=-\alpha
# \end{matrix}\right.$$
# $$s^*=\alpha-3$$
# $$t^*=\alpha-1$$
# $$-1+(\alpha-3)+(\alpha-1)=-\alpha$$
# $$3\alpha=5$$
# $$\alpha=\frac{5}{3}$$
# Com isso teremos:
# $P_1=(0,\frac{4}{3},\frac{1}{3})$ e $P_2=(\frac{5}{3},3,-\frac{4}{3})$

# %% [markdown]
# 4)Seja $l$ o lugar geométrico dos pontos $P(x,y)$ do plano cuxas coordenadas $x$ e $y$ satisfazem:
# $$4x^2-8x+9y^2+6y-33=0$$

# %% [markdown]
# a)Qual o tipo de cônica $l$?

# %% [markdown]
# Para fazer essa questão, basta plotarmos no geogebra e assim obteremos:
# ![image-2.png](attachment:image-2.png)
# Com isso da pra ver que é uma hipérbole.

# %% [markdown]
# b)Escrever a equação canônica de $l$.

# %% [markdown]
# $$4x^2-8x-9y^2-6y+33=0$$
# $$4(x^2-2x+1)-9(y^2-\frac{2}{3}y+\frac{1}{9})=36$$
# $$\frac{(x-1)^2}{3^2}-\frac{(y-\frac{1}{3})^2}{2^2}=1$$

# %% [markdown]
# c)Se ela for elipse ou hipérbole, encontrar os focos e a excentriciade de $l$. No caso de hipérbole, encontrar também equações das assíntotas no sistema $Oxy$.

# %% [markdown]
# Para encontrar o foco, basta escrever foco no geogebra e marcar a cônica e com isso teremos:
# ![image.png](attachment:image.png)
# $F_1=(-2.60, -0.33)$ e $F_2=(4.60, - 0.33)$
# Da mesma forma encontraremos a excentrecidade de  $l$, basta escrevermos excentrecidade no geogebra e marcar a  cônica para obtermos:
# ![image-2.png](attachment:image-2.png)
# Logo $e=1,20$
