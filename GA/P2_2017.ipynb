# %% [markdown]
# # Para iniciarmos a resolução dessa prova, irei apresentar todos os comandos utilizados, caso queira se interar mais no assunto, recomendo o material criado pelo professor Ricardo que se chama: *"Tutorial rápido de Python para Matemáticos"* e pode ser encontrado no link: (https://rmiranda99.github.io/tutorial-math-python/6-limites-derivadas-integrais.html) LINK ONDE ENCONTRA-SE A RESOLUÇÃO DESSA PROVA: (https://www.ime.unicamp.br/~andreani/MA141/Provas%20Anteriores/segundaprova16.05.2017diurno.pdf)

# %% [markdown]
# E também usaremos o matrix calc(https://matrixcalc.org/pt) para escalonar as matrizes e obtermos o estudo dos sistemas

# %% [markdown]
# 1) A)   Encontre equações paramétricas assim como uma equação linear que descrevam o plano contendo os pontos $(1,0,0),(1,2,-1)$ e $(0,-1,2)$.

# %% [markdown]
# Essa questão vamos resolve-la no GEOGEBRA 3D (https://www.geogebra.org/calculator). Primeiro iremos plotar os três pontos e ficará assim.
# ![image.png](attachment:image.png)
# Depois vamos em ferramentas e em planos por três pontos.
# ![image-2.png](attachment:image-2.png)
# Selecionar os três pontos para plotar o plano.
# ![image-3.png](attachment:image-3.png)
# E obtivemos a equação do plano que é:
# $-3x+2y-2z+3=0$
#
# Agora vamos parametrizá-la:
# $AB=(0,2,-1); CB=(1,3,-3)$
# A equação paramétrica do plano é:
# $(x,y,z)=(A)+t(AB)+s(CB)=(1,0,0)+t(0,2,-1)+s(1,3,-3)$
# $$\left\{\begin{array}{crl}
# x & = & 1+s \\
# y &  =& 2t+3s\\
# z &  =& -t-3s
# \end{array}\right.$$

# %% [markdown]
# b) Encontre a interseção do plano do item (a) com a reta determinada por $x+2z=1, y=2$

# %% [markdown]
# Primeiro vamos plotar os 2 planos que são: x+2z=1 e y=2:
# ![image.png](attachment:image.png)
# Para saber a equação da reta, vamos fazer a interseção deles que basicamente é pelo comando: interseção(plano1, plano)
# ![image-2.png](attachment:image-2.png)
# Com isso obtemos a equação da reta do item B.
# Agora vamos plotar novamente o plano do item A.
# ![image-3.png](attachment:image-3.png)
# Agora só fazer a interseção do plano com a reta.
# ![image-4.png](attachment:image-4.png)
# E obtemos o ponto $D=(0,2,\frac{1}{2})$

# %% [markdown]
# c) Determine o cosseno do ângulo formado pela reta e o plano dos itens anteriores

# %% [markdown]
# Primeiro, com o plano do Item A e a Reta do item B plotados, vamos procurar o angulo entre eles que é obtido com o comando ângulo(reta, plano)
# ![image.png](attachment:image.png)
# Sabendo que o ângulo é de 28,56º, basta calcular o cosseno dele que é de: 0,87

# %% [markdown]
# 2. Determine se a afirmação abaixo é verdadeira ou falsa.

# %% [markdown]
# a) Para quaisquer dois vetores v,w, $\left | \left | v-w \right | \right |\geq \left \| \left \| v \right \| \right \|-\left \| \left \| w \right \| \right \|$

# %% [markdown]
# $$\left \| u-w+v \right \|\leq \left \| u-w \right \|+\left \| v \right \|\Rightarrow $$
# $$\left \| u \right \|-\left \| v \right \|\leq \left \| u-w \right \| (1)$$
# $$\left \| w-u+u \right \|\leq \left \| w-u \right \|+\left \| u \right \|=\left \| u-w \right \|+\left \| u \right \|\Rightarrow $$
# $$-(\left \| u \right \|-\left \| v \right \|)\leq \left \| u-w \right \|(2)$$
# com (1) e (2) $$\Rightarrow \left \| \left \| u \right \| -\left \| v \right \|\right \|\leq \left \| u-v \right \|$$
# Verdadeiro.

# %% [markdown]
# b) Se os vetores u,v, w satisfazem $u\times v=u\times w $ então $v\times w=0$.

# %% [markdown]
# Seja: $u=(0,0,1), v=(0,1,0) , w=(0,1,1)$
# Logo:
# $u\times v=u\times w=-i$ \
# Mas:
# $v\times w=i$
# Logo é falso.

# %% [markdown]
# 3) Determine se os seguintes pontos do $\mathbb{R}^3$ são coplanares: $(1,0,1),(2,1,3),(1,1,1),(2,2,3)$.

# %% [markdown]
# AB= (1,1,2); AC=(0,1,0); AD=(1,2,2). Agora é só fazer a determinante.

# %%
import numpy as np 
from numpy import linalg 
matrix = np.array([[1, 1, 2], [0, 1, 0], [1, 2, 2]]) 
np.linalg.det(matrix)
# Out:
# 0.0

# %% [markdown]
# Como DET=0, eles são coplanares.

# %% [markdown]
# 4. Considere a reta $R_1$ que passa por $(0,0,1)$ e tem $v=(1,2,-1)$ como vetor diretor, assim como a reta $R_2$ dada por $\frac{x+1}{3}=\frac{y-1}{2}=z$

# %% [markdown]
# a) Encontre os pontos $P_1\in R_1$ e $P_2\in R_2$ que satisfazem $d(p_1,p_2)=d(R_1,R_2)$.

# %% [markdown]
# b) Encontre as projeções ortogonais da origem em $R_1$ e $R_2$. (A projeção ortogonal de um ponto $p$ em uma reta $R$ é a interseção de $R$ com a reta $S$ que contém $p$ e intersecta $R$ ortogonalmente.)

# %% [markdown]
# c) Encontre equações lineares dos planos $P_1$ e $P_2$ que contém $R_1$ e $R_2$, respectivamente, e satisfazem $d(P_1,P_2)=d(R_1,R_2)$
